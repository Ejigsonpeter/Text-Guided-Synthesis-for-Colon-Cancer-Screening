# %%
# !pip install huggingface-hub
# !pip install diffusers
# !pip install segment-anything
# !pip install lama-cleane
# Out:
# Requirement already satisfied: huggingface-hub in c:\users\sage0\anaconda3\lib\site-packages (0.24.6)
# Requirement already satisfied: filelock in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (6.0)
# Requirement already satisfied: requests in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub) (4.7.1)
# Requirement already satisfied: colorama in c:\users\sage0\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sage0\anaconda3\lib\site-packages (from requests->huggingface-hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sage0\anaconda3\lib\site-packages (from requests->huggingface-hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sage0\anaconda3\lib\site-packages (from requests->huggingface-hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sage0\anaconda3\lib\site-packages (from requests->huggingface-hub) (2023.7.22)
# Collecting diffusers
#   Obtaining dependency information for diffusers from https://files.pythonhosted.org/packages/74/2b/69bb842f7567cd92a540f8a9a63a20e09304ad8ff84530f26762e7e19626/diffusers-0.30.0-py3-none-any.whl.metadata
#   Downloading diffusers-0.30.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: importlib-metadata in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (6.0.0)
# Requirement already satisfied: filelock in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (3.9.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (0.24.6)
# Requirement already satisfied: numpy in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (0.4.2)
# Requirement already satisfied: Pillow in c:\users\sage0\anaconda3\lib\site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (6.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sage0\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\sage0\anaconda3\lib\site-packages (from importlib-metadata->diffusers) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sage0\anaconda3\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sage0\anaconda3\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sage0\anaconda3\lib\site-packages (from requests->diffusers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sage0\anaconda3\lib\site-packages (from requests->diffusers) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\sage0\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.2->diffusers) (0.4.6)
# Downloading diffusers-0.30.0-py3-none-any.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB 1.4 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/2.6 MB 1.7 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.6 MB 3.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 5.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.6 MB 5.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 6.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: diffusers
# Successfully installed diffusers-0.30.0
# Collecting segment-anything
#   Obtaining dependency information for segment-anything from https://files.pythonhosted.org/packages/75/77/8e0c16abf151a1dd076b562febc0da2ecf1132b0b41826087af96f101f42/segment_anything-1.0-py3-none-any.whl.metadata
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Installing collected packages: segment-anything
# Successfully installed segment-anything-1.0
# ERROR: Could not find a version that satisfies the requirement lama-cleane (from versions: none)
# ERROR: No matching distribution found for lama-cleane

# %%
import os
import cv2
import numpy as np
from segment_anything import sam_model_registry, SamPredictor
from PIL import Image

def detect_circles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    blurred = cv2.GaussianBlur(gray, (9, 9), 2)
    circles = cv2.HoughCircles(blurred, cv2.HOUGH_GRADIENT, dp=1, minDist=50,
                               param1=50, param2=30, minRadius=20, maxRadius=100)
    
    if circles is not None:
        circles = np.round(circles[0, :]).astype("int")
    return circles

def generate_masks(input_folder, output_folder, sam_checkpoint):
    os.makedirs(output_folder, exist_ok=True)

    # Initialize SAM
    sam = sam_model_registry["default"](checkpoint=sam_checkpoint)
    predictor = SamPredictor(sam)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(input_folder, filename)
            image = cv2.imread(image_path)
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Detect circles
            circles = detect_circles(image_rgb)

            if circles is not None:
                # Set image for SAM predictor
                predictor.set_image(image_rgb)

                # Create a blank black image for the final mask
                final_mask = np.zeros(image.shape[:2], dtype=np.uint8)

                for (x, y, r) in circles:
                    # Generate points around the circle
                    num_points = 12
                    points = []
                    for i in range(num_points):
                        angle = 2 * np.pi * i / num_points
                        px = int(x + r * np.cos(angle))
                        py = int(y + r * np.sin(angle))
                        points.append([px, py])

                    # Get masks from SAM
                    input_point = np.array(points)
                    input_label = np.array([1] * len(points))  # 1 for foreground
                    masks, _, _ = predictor.predict(
                        point_coords=input_point,
                        point_labels=input_label,
                        multimask_output=False
                    )

                    # Add the mask to the final mask
                    final_mask = np.logical_or(final_mask, masks[0]).astype(np.uint8)

                # Convert boolean mask to uint8 (0 and 255)
                final_mask = (final_mask * 255).astype(np.uint8)

                # Save the mask
                output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_mask.png")
                Image.fromarray(final_mask).save(output_path)

                print(f"Processed {filename}")
            else:
                print(f"No circles detected in {filename}")

    print("All images processed.")

# Usage
input_folder = "synthetic"
output_folder = "synthetic_mask"
sam_checkpoint = "sam_vit_h_4b8939.pth"

generate_masks(input_folder, output_folder, sam_checkpoint)
# Out:
# Processed image_1003 - Copy.png
# Processed image_101.png
# No circles detected in image_104 - Copy.png
# No circles detected in image_105 - Copy.png
# Processed image_1062 - Copy.png
# No circles detected in image_1098 - Copy.png
# No circles detected in image_111.png
# No circles detected in image_1126 - Copy.png
# Processed image_1167 - Copy.png
# Processed image_1180 - Copy.png
# Processed image_1180.png
# Processed image_1183 - Copy.png
# No circles detected in image_119.png
# No circles detected in image_1200 - Copy.png
# Processed image_1239 - Copy.png
# No circles detected in image_124 - Copy.png
# Processed image_1266 - Copy.png
# No circles detected in image_1279 - Copy.png
# Processed image_1288.png
# Processed image_1299 - Copy.png
# Processed image_1303 - Copy.png
# Processed image_1310 - Copy.png
# No circles detected in image_1343 - Copy.png
# Processed image_135.png
# No circles detected in image_136 - Copy.png
# No circles detected in image_1361 - Copy.png
# Processed image_1369 - Copy.png
# Processed image_1369.png
# No circles detected in image_1372 - Copy.png
# No circles detected in image_1410 - Copy.png
# No circles detected in image_1443 - Copy.png
# Processed image_1446 - Copy.png
# Processed image_1456 - Copy.png
# Processed image_1464.png
# No circles detected in image_1469 - Copy.png
# No circles detected in image_148.png
# No circles detected in image_1487 - Copy.png
# Processed image_150.png
# No circles detected in image_1508 - Copy.png
# No circles detected in image_152.png
# Processed image_1534 - Copy.png
# Processed image_1541 - Copy.png
# No circles detected in image_1561 - Copy.png
# Processed image_1564 - Copy.png
# No circles detected in image_1600 - Copy.png
# Processed image_1610 - Copy.png
# Processed image_163 - Copy.png
# No circles detected in image_1631 - Copy.png
# No circles detected in image_1659.png
# Processed image_166 - Copy.png
# No circles detected in image_1677 - Copy.png
# Processed image_1680 - Copy.png
# No circles detected in image_170.png
# No circles detected in image_171.png
# Processed image_1749 - Copy.png
# No circles detected in image_1752 - Copy.png
# Processed image_1758 - Copy.png
# No circles detected in image_1800 - Copy.png
# Processed image_1835 - Copy.png
# No circles detected in image_184 - Copy.png
# No circles detected in image_1857 - Copy.png
# Processed image_1888 - Copy.png
# No circles detected in image_1953 - Copy.png
# Processed image_1971 - Copy.png
# Processed image_202 - Copy.png
# Processed image_2049 - Copy.png
# Processed image_207.png
# No circles detected in image_208.png
# Processed image_2110 - Copy.png
# Processed image_2122 - Copy.png
# No circles detected in image_2154 - Copy.png
# No circles detected in image_224.png
# No circles detected in image_2276 - Copy.png
# No circles detected in image_2279.png
# No circles detected in image_2324.png
# Processed image_2393 - Copy.png
# No circles detected in image_240.png
# Processed image_241.png
# Processed image_2432 - Copy.png
# Processed image_2443 - Copy.png
# Processed image_2447 - Copy.png
# No circles detected in image_245.png
# Processed image_249.png
# Processed image_2491 - Copy.png
# Processed image_2524 - Copy.png
# No circles detected in image_259.png
# No circles detected in image_264.png
# No circles detected in image_276.png
# No circles detected in image_284.png
# No circles detected in image_296.png
# No circles detected in image_297.png
# Processed image_30 - Copy.png
# No circles detected in image_303.png
# No circles detected in image_317.png
# No circles detected in image_326.png
# Processed image_330.png
# No circles detected in image_331.png
# No circles detected in image_351.png
# Processed image_367.png
# No circles detected in image_370.png
# No circles detected in image_376.png
# No circles detected in image_384.png
# No circles detected in image_39 - Copy.png
# No circles detected in image_390.png
# Processed image_406 - Copy.png
# Processed image_408 - Copy.png
# Processed image_415.png
# Processed image_42.png
# No circles detected in image_420.png
# No circles detected in image_433.png
# No circles detected in image_439 - Copy.png
# No circles detected in image_449.png
# Processed image_457.png
# Processed image_461 - Copy.png
# No circles detected in image_465.png
# No circles detected in image_473.png
# Processed image_483.png
# Processed image_485.png
# No circles detected in image_491.png
# No circles detected in image_506 - Copy.png
# Processed image_513 - Copy.png
# No circles detected in image_52.png
# Processed image_537.png
# No circles detected in image_568.png
# Processed image_571 - Copy.png
# No circles detected in image_590 - Copy.png
# No circles detected in image_592.png
# Processed image_600.png
# Processed image_603 - Copy.png
# No circles detected in image_608.png
# Processed image_611 - Copy.png
# No circles detected in image_612.png
# Processed image_615.png
# Processed image_623.png
# No circles detected in image_63 - Copy.png
# No circles detected in image_646 - Copy.png
# No circles detected in image_701 - Copy.png
# Processed image_723 - Copy.png
# No circles detected in image_739 - Copy.png
# No circles detected in image_76.png
# Processed image_765 - Copy.png
# Processed image_79 - Copy.png
# Processed image_811 - Copy.png
# Processed image_853 - Copy.png
# No circles detected in image_89 - Copy.png
# No circles detected in image_894 - Copy.png
# Processed image_90 - Copy.png
# No circles detected in image_918 - Copy.png
# No circles detected in image_99.png
# No circles detected in image_992 - Copy.png
# All images processed.
